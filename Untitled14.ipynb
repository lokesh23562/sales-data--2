# %% [markdown]
# <a href="https://colab.research.google.com/github/lokesh23562/sales-data--2/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("/content/sample_data/sales_data (2).csv")

print(df.head())
print(df.info())

# Cleaning
df.dropna(inplace=True)
# Out:
#          Date     Product  Quantity  Price Customer_ID Region  Total_Sales
# 0  2024-01-01       Phone         7  37300     CUST001   East       261100
# 1  2024-01-02  Headphones         4  15406     CUST002  North        61624
# 2  2024-01-03       Phone         2  21746     CUST003   West        43492
# 3  2024-01-04  Headphones         1  30895     CUST004   East        30895
# 4  2024-01-05      Laptop         8  39835     CUST005  North       318680
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         100 non-null    object
#  1   Product      100 non-null    object
#  2   Quantity     100 non-null    int64
#  3   Price        100 non-null    int64
#  4   Customer_ID  100 non-null    object
#  5   Region       100 non-null    object
#  6   Total_Sales  100 non-null    int64
# dtypes: int64(3), object(4)
# ...

# %% [markdown]
# Basic Analysis

# %%
# Total sales
total_sales = df["Total_Sales"].sum()

# Sales by product (since 'Category' doesn't exist)
sales_by_product = df.groupby("Product")["Total_Sales"].sum()

# Monthly sales
df["Month"] = pd.to_datetime(df["Date"]).dt.month
monthly_sales = df.groupby("Month")["Total_Sales"].sum()

print(f"Total Sales: {total_sales}")
print("\nSales by Product:")
print(sales_by_product)
print("\nMonthly Sales:")
print(monthly_sales)
# Out:
# Total Sales: 12365048
#
# Sales by Product:
# Product
# Headphones    1384033
# Laptop        3889210
# Monitor       1348071
# Phone         2859394
# Tablet        2884340
# Name: Total_Sales, dtype: int64
#
# Monthly Sales:
# Month
# 1    4120524
# 2    2656050
# 3    4485006
# 4    1103468
# Name: Total_Sales, dtype: int64

# %% [markdown]
# Data Visualization (Matplotlib)
# 📊 Bar Chart – Sales by Category

# %%
import matplotlib.pyplot as plt

# Using sales_by_product as defined in the previous cell
sales_by_product.plot(kind="bar")
plt.title("Sales by Product")
plt.xlabel("Product")
plt.ylabel("Sales")
plt.tight_layout()
# Ensure the directory exists if you plan to save
import os
os.makedirs("visualizations", exist_ok=True)
plt.savefig("visualizations/sales_by_product.png")
plt.show()

# %% [markdown]
# Line Chart – Monthly Sales Trend

# %%
# Sales by Region
sales_by_region = df.groupby("Region")["Total_Sales"].sum()

print("Sales by Region:")
print(sales_by_region)

# Visualization - Sales by Region
plt.figure(figsize=(8, 5))
sales_by_region.plot(kind="pie", autopct='%1.1f%%', startangle=140)
plt.title("Sales Distribution by Region")
plt.ylabel("") # Remove the y-label for pie charts
plt.savefig("visualizations/sales_by_region.png")
plt.show()
# Out:
# Sales by Region:
# Region
# East     2519639
# North    3983635
# South    3737852
# West     2123922
# Name: Total_Sales, dtype: int64

# %% [markdown]
# pie chart sales share

# %%
# Visualization - Monthly Sales Trend
plt.figure(figsize=(10, 6))
monthly_sales.plot(kind='line', marker='o', color='b', linestyle='-')
plt.title('Monthly Sales Trend')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.xticks(monthly_sales.index)
plt.grid(True)
plt.tight_layout()
plt.savefig('visualizations/monthly_sales_trend.png')
plt.show()

# %%
# Using sales_by_product as defined in previous analysis cells
sales_by_product.plot(kind="pie", autopct="%1.1f%%")
plt.title("Sales Distribution by Product")
plt.ylabel("")
plt.tight_layout()
plt.savefig("visualizations/sales_share.png")
plt.show()
